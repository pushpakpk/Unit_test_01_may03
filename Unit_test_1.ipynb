# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"sales.csv", encoding = 'unicode_escape')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# 1 drop unrelated columns
# 2 check for null values
# 3 drop null values
# 4 what is the average age of customers?
# 5 who are the majority buyers?(genderwise)
# 6

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %% [markdown]
# # Q1 drop unrelated columns

# %%
df.drop(['Status','unnamed1'], axis=1,inplace = True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# Q 2 check for null values

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# Q3  drop null values

# %%
df["Amount"].fillna(" ",inplace = True)

# %%
#df.isnull().sum()
df.dropna()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# #### Q4 what is the average age of customers?

# %%
average = df['Age'].mean()

# %%
average
# Out:
# 35.421207003821884

# %% [markdown]
# # Q5who are the majority buyers?(genderwise)

# %%
sns.countplot(x = 'Gender', hue = 'Orders',data = df,palette = 'Set1')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = 'Gender',data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# # Q6 where do our majority customers fall(age)?

# %%
df.groupby(['Age'])['Orders'].count()
# Out:
# Age
# 12    51
# 13    53
# 14    32
# 15    53
# 16    61
#       ..
# 88    11
# 89    15
# 90    11
# 91     9
# 92     7
# Name: Orders, Length: 81, dtype: int64

# %%
age_data = df['Age']

plt.hist(age_data, bins = 21)

plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Q7 which state has highest sales?

# %%
df.groupby(['State'])['Amount'].count()
# Out:
# State
# Andhra Pradesh       812
# Bihar                434
# Delhi               1107
# Gujarat              429
# Haryana              452
# Himachal Pradesh     608
# Jharkhand            380
# Karnataka           1305
# Kerala               453
# Madhya Pradesh       923
# Maharashtra         1526
# Punjab               200
# Rajasthan            231
# Telangana            125
# Uttar Pradesh       1946
# Uttarakhand          320
# Name: Amount, dtype: int64

# %% [markdown]
# Q8

# %%
#Q8
plt.figure(figsize=(20,5))
sns.countplot(x=df['Occupation'], palette = 'Set1',edgecolor='black')
plt.show()

# %% [markdown]
# Q9

# %%
top10= df['Product_Category'].value_counts().head(10).reset_index()
top10
# Out:
#                    index  Product_Category
# 0     Clothing & Apparel              2655
# 1                   Food              2493
# 2  Electronics & Gadgets              2087
# 3       Footwear & Shoes              1064
# 4        Household items               520
# 5                 Beauty               422
# 6           Games & Toys               386
# 7        Sports Products               356
# 8              Furniture               353
# 9               Pet Care               212

# %% [markdown]
# Q10

# %%
name = input("Enter your name: ")


#def welcome(name):
print(f"{name},welcome to symbi")
# Out:
# Enter your name: pushpak
# pushpak,welcome to symbi
